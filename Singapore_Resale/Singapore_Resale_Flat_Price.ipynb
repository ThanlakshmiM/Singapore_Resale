# %%
import pandas as pd
df1=pd.read_csv("/content/ResaleFlatPricesBasedonApprovalDate19901999.csv")
df2=pd.read_csv("/content/ResaleFlatPricesBasedonApprovalDate2000Feb2012.csv")
df3=pd.read_csv("/content/ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014.csv")
df4=pd.read_csv("/content/ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv")
df5=pd.read_csv("/content/ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv")

# %%
# Create a list of dataframes
df_list = [df1, df2, df3, df4, df5]

# Concatenate the dataframes
df = pd.concat(df_list)

# Print the concatenated dataframe
df
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 174237  2024-03      YISHUN     5 ROOM   231      YISHUN ST 21     07 TO 09
# 174238  2024-03      YISHUN     5 ROOM  513C      YISHUN ST 51     04 TO 06
# 174239  2024-03      YISHUN     5 ROOM   637      YISHUN ST 61     10 TO 12
# 174240  2024-03      YISHUN  EXECUTIVE   791      YISHUN AVE 2     10 TO 12
# 174241  2024-03      YISHUN  EXECUTIVE   606      YISHUN ST 61     07 TO 09
#
# ...

# %%
#download csv file
df.to_csv('ResaleFlatPrice1990-2023',index=False)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df=pd.read_csv("/content/ResaleFlatPrice1990-2023")

# %%
df
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 920440  2024-03      YISHUN     5 ROOM   231      YISHUN ST 21     07 TO 09
# 920441  2024-03      YISHUN     5 ROOM  513C      YISHUN ST 51     04 TO 06
# 920442  2024-03      YISHUN     5 ROOM   637      YISHUN ST 61     10 TO 12
# 920443  2024-03      YISHUN  EXECUTIVE   791      YISHUN AVE 2     10 TO 12
# 920444  2024-03      YISHUN  EXECUTIVE   606      YISHUN ST 61     07 TO 09
#
# ...

# %%
df.isna().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# dtype: int64

# %%
df
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 920440  2024-03      YISHUN     5 ROOM   231      YISHUN ST 21     07 TO 09
# 920441  2024-03      YISHUN     5 ROOM  513C      YISHUN ST 51     04 TO 06
# 920442  2024-03      YISHUN     5 ROOM   637      YISHUN ST 61     10 TO 12
# 920443  2024-03      YISHUN  EXECUTIVE   791      YISHUN AVE 2     10 TO 12
# 920444  2024-03      YISHUN  EXECUTIVE   606      YISHUN ST 61     07 TO 09
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920445 entries, 0 to 920444
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                920445 non-null  object
#  1   town                 920445 non-null  object
#  2   flat_type            920445 non-null  object
#  3   block                920445 non-null  object
#  4   street_name          920445 non-null  object
#  5   storey_range         920445 non-null  object
#  6   floor_area_sqm       920445 non-null  float64
#  7   flat_model           920445 non-null  object
#  8   lease_commence_date  920445 non-null  int64
#  9   resale_price         920445 non-null  float64
#  10  remaining_lease      211395 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 77.2+ MB

# %%
# Unique values in each column
for i in df:
  print(f"{i}=",df[i].nunique())
# Out:
# month= 411
# town= 27
# flat_type= 8
# block= 2706
# street_name= 584
# storey_range= 25
# floor_area_sqm= 211
# flat_model= 34
# lease_commence_date= 56
# resale_price= 9416
# remaining_lease= 770

# %%
for i in df:
  print(f"{i}=",df[i].unique())
# Out:
# town= [ 0  1  2  3  4  6  7  8  9 10 11 12 13 14 16 19 21 22 23 24 25 26 15 20
#   5 17 18]
# number_of_rooms= [0 2 3 4 1 5]
# storey= [ 5  2  4  0  7 10  8 13 12 15 16 21 20 18  3  1  6  9 11 14 19 17 23 22
#  24]
# floor_area_sqm= [ 31.   73.   67.   82.   74.   88.   89.   83.   68.   75.   81.   91.
#   92.   97.   90.   98.   99.  100.   93.  103.  119.  120.  118.  121.
#  135.  117.   45.   65.   59.   70.   76.   84.  104.  105.  125.  132.
#  139.  123.  143.  151.   69.  106.  107.  116.  149.  141.  146.  148.
#  145.  154.  150.   29.   51.   61.   63.   64.   72.   58.   66.   60.
#   53.   54.   56.   77.  133.  131.  115.   43.   38.   41.   85.  111.
#  101.  112.  137.  127.  147.  163.   50.   40.   60.3  62.   55.   57.
#   52.   63.1 102.   83.1 126.  140.  142.   71.  108.  144.   96.  114.
#  157.  152.  155.   87.  109.  110.   94.  134.  122.  128.   78.   46.
#   42.   49.   47.   86.  156.   79.   80.  124.   28.  113.   95.  160.
# ...

# %%
# After droping the column
df.isna().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# dtype: int64

# %%
df['flat_type'] = df['flat_type'].str.replace(r'MULTI-GENERATION','MULTI GENERATION',regex=True)

# %%
# Visualize the distribution of the flat_model column
print(df['flat_model'].nunique())
df['flat_model'].unique()
# Out:
# 34
# array(['IMPROVED', 'NEW GENERATION', 'MODEL A', 'STANDARD', 'SIMPLIFIED',
#        'MODEL A-MAISONETTE', 'APARTMENT', 'MAISONETTE', 'TERRACE',
#        '2-ROOM', 'IMPROVED-MAISONETTE', 'MULTI GENERATION',
#        'PREMIUM APARTMENT', 'Improved', 'New Generation', 'Model A',
#        'Standard', 'Apartment', 'Simplified', 'Model A-Maisonette',
#        'Maisonette', 'Multi Generation', 'Adjoined flat',
#        'Premium Apartment', 'Terrace', 'Improved-Maisonette',
#        'Premium Maisonette', '2-room', 'Model A2', 'DBSS', 'Type S1',
#        'Type S2', 'Premium Apartment Loft', '3Gen'], dtype=object)

# %%
# Converting the flat_model column to lowercase
df['flat_model'] = df['flat_model'].str.lower()
# Unique lables in flat_model column
df['flat_model'].nunique()
# Out:
# 21

# %%
df.flat_type.unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION'], dtype=object)

# %%
# Splitting month col
month=df['month'].str.split('-',expand = True)
month.head()
# Out:
#       0   1
# 0  1990  01
# 1  1990  01
# 2  1990  01
# 3  1990  01
# 4  1990  01

# %%
# Creating the year values as column
df.insert(loc = 1,
          column = 'selling_year',
          value = month[0])
# Creating the month values as column
df.insert(loc = 2,
          column = 'selling_month',
          value = month[1])

# %%
df.columns
# Out:
# Index(['selling_year', 'selling_month', 'town', 'flat_type', 'block',
#        'street_name', 'storey_range', 'floor_area_sqm', 'flat_model',
#        'lease_commence_date', 'resale_price', 'remaining_lease'],
#       dtype='object')

# %%
df.drop('month',axis = 1,inplace = True)

# %%
df
# Out:
#        selling_year selling_month        town  flat_type block  \
# 0              1990            01  ANG MO KIO     1 ROOM   309
# 1              1990            01  ANG MO KIO     1 ROOM   309
# 2              1990            01  ANG MO KIO     1 ROOM   309
# 3              1990            01  ANG MO KIO     1 ROOM   309
# 4              1990            01  ANG MO KIO     3 ROOM   216
# ...             ...           ...         ...        ...   ...
# 920440         2024            03      YISHUN     5 ROOM   231
# 920441         2024            03      YISHUN     5 ROOM  513C
# 920442         2024            03      YISHUN     5 ROOM   637
# 920443         2024            03      YISHUN  EXECUTIVE   791
# 920444         2024            03      YISHUN  EXECUTIVE   606
#
#              street_name storey_range  floor_area_sqm      flat_model  \
# 0       ANG MO KIO AVE 1     10 TO 12            31.0        improved
# ...

# %%
df.remaining_lease.unique()
# Out:
# array([nan, 70.0, 65.0, 64.0, 63.0, 62.0, 69.0, 60.0, 61.0, 86.0, 77.0,
#        80.0, 90.0, 87.0, 66.0, 58.0, 94.0, 71.0, 68.0, 84.0, 73.0, 79.0,
#        76.0, 72.0, 82.0, 74.0, 67.0, 88.0, 81.0, 89.0, 53.0, 54.0, 55.0,
#        57.0, 93.0, 83.0, 85.0, 92.0, 91.0, 59.0, 95.0, 52.0, 51.0, 56.0,
#        75.0, 96.0, 78.0, 50.0, 97.0, '67', '66', '70', '71', '68', '81',
#        '88', '76', '58', '53', '57', '62', '59', '50', '54', '56', '60',
#        '52', '86', '69', '78', '80', '92', '89', '87', '61', '63', '64',
#        '83', '72', '73', '82', '85', '94', '75', '77', '79', '65', '95',
#        '90', '74', '91', '84', '93', '55', '96', '51', '49', '48',
#        '61 years 04 months', '60 years 07 months', '62 years 05 months',
#        '62 years 01 month', '63 years', '61 years 06 months',
#        '58 years 04 months', '59 years 08 months', '59 years 06 months',
#        '60 years', '62 years 08 months', '61 years', '60 years 10 months',
# ...

# %%
# to convert Years and months in 'remaining_lease' column into a 'float' variable
df['Remaining_lease_float'] = (pd.to_numeric(df['remaining_lease'].str.extractall('(\d+)')[0])
                 .unstack().div([1, 12]).sum(axis=1)
                 .round(2))

# %%
df=df.drop('remaining_lease',axis=1)

# %%
columns_modes = df[['Remaining_lease_float']].mean().iloc[0]
df[['Remaining_lease_float']] = df[['Remaining_lease_float']].fillna(columns_modes)

# %%
df.isna().sum()
# Out:
# selling_year             0
# selling_month            0
# town                     0
# flat_type                0
# block                    0
# street_name              0
# storey_range             0
# floor_area_sqm           0
# flat_model               0
# lease_commence_date      0
# resale_price             0
# Remaining_lease_float    0
# dtype: int64

# %%
df
# Out:
#        selling_year selling_month        town  flat_type block  \
# 0              1990            01  ANG MO KIO     1 ROOM   309
# 1              1990            01  ANG MO KIO     1 ROOM   309
# 2              1990            01  ANG MO KIO     1 ROOM   309
# 3              1990            01  ANG MO KIO     1 ROOM   309
# 4              1990            01  ANG MO KIO     3 ROOM   216
# ...             ...           ...         ...        ...   ...
# 920440         2024            03      YISHUN     5 ROOM   231
# 920441         2024            03      YISHUN     5 ROOM  513C
# 920442         2024            03      YISHUN     5 ROOM   637
# 920443         2024            03      YISHUN  EXECUTIVE   791
# 920444         2024            03      YISHUN  EXECUTIVE   606
#
#              street_name storey_range  floor_area_sqm      flat_model  \
# 0       ANG MO KIO AVE 1     10 TO 12            31.0        improved
# ...

# %%
# Loop through the elements of the mixed column
#for i in df['remaining_lease']:
    # Convert i to a string
 #   i = str(i)
    # Use regular expression to extract numerical values
  #  match = re.match(r"(\d+) years (\d+) months", i)
   # if match:
        # Extract years and months and convert to integers
    #    df['remaining_lease'] = (float(match.group(1)))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Visualize the distribution of the resale price column
sns.histplot(df['resale_price'], bins = 20)
plt.title('Distribution of resale price')

plt.show()

# %%
# Visualize the distribution of the flat_type column
plt.figure(figsize=(10, 6))
sns.barplot(x = df['flat_type'], y = df['resale_price'],color='pink')
plt.xlabel('Flat Type')
plt.ylabel('Price')
plt.show()

# %%
# Visualize the distribution of the lease_commence_date column
plt.figure(figsize=(25, 10))
sns.scatterplot(x = df['lease_commence_date'], y = df['resale_price'],color='red')
plt.xticks(rotation = 25)
plt.xlabel('lease_commence_date')
plt.ylabel('Resale_Price')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df.lease_commence_date.unique()
# Out:
# array([1977, 1976, 1978, 1979, 1984, 1980, 1985, 1981, 1982, 1986, 1972,
#        1983, 1973, 1969, 1975, 1971, 1974, 1967, 1970, 1968, 1988, 1987,
#        1989, 1990, 1992, 1993, 1994, 1991, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 1966, 2002, 2006, 2003, 2005, 2004, 2008, 2007, 2009,
#        2010, 2012, 2011, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2022,
#        2020])

# %%
# Visualize the distribution of the town column
plt.figure(figsize=(25, 10))
sns.boxplot(x = df['town'], y = df['resale_price'],color='green')
plt.xticks(rotation = 25)
plt.xlabel('town')
plt.ylabel('Resale_Price')
plt.show()

# %%
# Visualize the distribution of the storey column
plt.figure(figsize=(25, 10))
sns.countplot(df['storey'],color='orange')
plt.xticks(rotation = 25)
plt.xlabel('storey')
plt.ylabel('Resale_Price')
plt.show()

# %%
plt.figure(figsize=(25, 10))
res = sns.lineplot(x="selling_year", y="resale_price", data=df)
plt.xticks(rotation = 25)
plt.show()

# %%
plt.figure(figsize=(25, 10))
res = sns.lineplot(x="selling_month", y="resale_price", data=df)
plt.xticks(rotation = 25)
plt.show()

# %%
res = sns.violinplot(y="Remaining_lease_float", data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['selling_year', 'selling_month', 'town', 'number_of_rooms', 'block',
#        'street_name', 'storey', 'floor_area_sqm', 'flat_model',
#        'lease_commence_date', 'resale_price', 'Remaining_lease_float'],
#       dtype='object')

# %%
plt.figure(figsize=(25, 10))
res = sns.pointplot(x=df['town'], y=df['floor_area_sqm'])
plt.xticks(rotation = 25)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920445 entries, 0 to 920444
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   selling_year           920445 non-null  object
#  1   selling_month          920445 non-null  object
#  2   town                   920445 non-null  object
#  3   flat_type              920445 non-null  object
#  4   block                  920445 non-null  object
#  5   street_name            920445 non-null  object
#  6   storey_range           920445 non-null  object
#  7   floor_area_sqm         920445 non-null  float64
#  8   flat_model             920445 non-null  object
#  9   lease_commence_date    920445 non-null  int64
#  10  resale_price           920445 non-null  float64
#  11  Remaining_lease_float  920445 non-null  float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 84.3+ MB

# %%
df['selling_month'] = df['selling_month'].astype('int64')
df['selling_year']=df['selling_year'].astype('int64')
#df['block']=df['bloc#k'].astype('int64')

# %%
df.block.unique()
# Out:
# array(['309', '216', '211', ..., '438C', '606C', '605D'], dtype=object)

# %%
len(df.block.unique())
# Out:
# 2706

# %%
df
# Out:
#         selling_year  selling_month        town  flat_type block  \
# 0               1990              1  ANG MO KIO     1 ROOM   309
# 1               1990              1  ANG MO KIO     1 ROOM   309
# 2               1990              1  ANG MO KIO     1 ROOM   309
# 3               1990              1  ANG MO KIO     1 ROOM   309
# 4               1990              1  ANG MO KIO     3 ROOM   216
# ...              ...            ...         ...        ...   ...
# 920440          2024              3      YISHUN     5 ROOM   231
# 920441          2024              3      YISHUN     5 ROOM  513C
# 920442          2024              3      YISHUN     5 ROOM   637
# 920443          2024              3      YISHUN  EXECUTIVE   791
# 920444          2024              3      YISHUN  EXECUTIVE   606
#
#              street_name storey_range  floor_area_sqm      flat_model  \
# 0       ANG MO KIO AVE 1     10 TO 12            31.0        improved
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
def preprocess(df):
    le=LabelEncoder()
    df["town"]=le.fit_transform(df["town"])
    df["flat_type"]=le.fit_transform(df["flat_type"])
    df["storey_range"]=le.fit_transform(df["storey_range"])
    df['block']=le.fit_transform(df['block'])
    df['street_name']=le.fit_transform(df['street_name'])
    df['flat_model']=le.fit_transform(df['flat_model'])

# %%
preprocess(df)

# %%
plt.figure(figsize = (12,8))
sns.boxplot(data = df)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.boxplot(df['town'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e7f39d21210>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e7f39d21750>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e7f39d20f70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e7f39d21c90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e7f39d21f30>],
#  'means': []}

# %%
plt.boxplot(df['storey'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f39dc1a9420>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f39dc1aa0b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f39dc1abb20>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f39dc1aa740>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f39dc1a9b70>],
#  'means': []}

# %%
plt.boxplot(df['number_of_rooms'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f39e6872020>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f39e6873a60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f39e6873820>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f39e6872c20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f39e6872920>],
#  'means': []}

# %%
df.lease_commence_date.unique()
# Out:
# array([1977, 1976, 1978, 1979, 1984, 1980, 1985, 1981, 1982, 1986, 1972,
#        1983, 1973, 1969, 1975, 1971, 1974, 1967, 1970, 1968, 1988, 1987,
#        1989, 1990, 1992, 1993, 1994, 1991, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 1966, 2002, 2003, 2005, 2006, 2004, 2008, 2007, 2009,
#        2010, 2012, 2011, 2013, 2014, 2015, 2016, 2017, 2019, 2018, 2020])

# %%
plt.boxplot(df['lease_commence_date'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78923d3104c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78923d310a00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78923d310220>],
#  'medians': [<matplotlib.lines.Line2D at 0x78923d310f40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78923d3111e0>],
#  'means': []}

# %%
from scipy.stats import skew
for i in df.columns:
  print(i,df[i].skew())
# Out:
# selling_year 0.2951072279677939
# selling_month -0.039507925793557226
# town -0.08504852789270825
# flat_type 0.38969261178555586
# block 0.2564797132909006
# street_name 0.023043790722929416
# storey_range 1.099489091876023
# floor_area_sqm 0.3668999928003579
# flat_model 0.4991382928909888
# lease_commence_date 0.6377038171198002
# resale_price 0.931610271529209
# Remaining_lease_float 0.016915564328596564

# %%
plt.boxplot(df['resale_price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7e7f05ef04f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7e7f05ef0910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7e7f05ef0250>],
#  'medians': [<matplotlib.lines.Line2D at 0x7e7f05ef0e50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7e7f05ef10f0>],
#  'means': []}

# %% [markdown]
# **Detect the outliers using IQR method**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def plot(columns):
  for i in columns:
     plt.figure(figsize=(16,5))
     plt.subplot(1,2,1)
     sns.distplot(df[i])
     plt.subplot(1,2,2)
     sns.boxplot(data=df,x=i)
     plt.show()

# %%
plot(df.columns)

# %%
import numpy as np
def treat_outliers(columns):
    for i in columns:
        percentile25 = df[i].quantile(0.25)
        percentile75 = df[i].quantile(0.75)
        iqr = percentile75 - percentile25      # IQR = Q3 - Q1
        upper_limit = percentile75 + 1.5 * iqr
        lower_limit = percentile25 - 1.5 * iqr
        df[i]= np.where(df[i] > upper_limit, upper_limit, np.where(df[i] < lower_limit, lower_limit, df[i]))
    print('successful')
treat_outliers(['floor_area_sqm','storey_range','resale_price','lease_commence_date','Remaining_lease_float'])
# Out:
# successful

# %%
import seaborn as sns
import matplotlib.pyplot as plt
def plot(columns):
    for i in columns:
     plt.figure(figsize=(16,5))
     plt.subplot(1,2,1)
     sns.distplot(df[i])
     plt.subplot(1,2,2)
     sns.boxplot(data=df,x=i)
     plt.show()
plot(['floor_area_sqm','storey_range','resale_price','lease_commence_date','Remaining_lease_float'])

# %% [markdown]
# before skewness

# %%
df.columns
# Out:
# Index(['selling_year', 'selling_month', 'town', 'flat_type', 'block',
#        'street_name', 'storey_range', 'floor_area_sqm', 'flat_model',
#        'lease_commence_date', 'resale_price', 'Remaining_lease_float'],
#       dtype='object')

# %%
columns=['Remaining_lease_float','resale_price']
def before_skewness(df,i):
         sns.set_style("darkgrid")
         sns.histplot(data=df, x=i, kde=True, bins=50, color='r')
         plt.title(f'Skewness In {i}')
         plt.show()



for i in columns:
    before_skewness(df,i)

# %% [markdown]
# after treating skewness in log_transformation

# %%
import numpy as np
def log_transformation(columns):
    for i in columns:
        df[i] = np.log(df[i])

log_transformation(['Remaining_lease_float','resale_price'])

# %%
def after_skewness(df,i):
         sns.set_style("darkgrid")
         sns.histplot(data=df, x=i, kde=True, bins=50, color='r')
         plt.title(f'Skewness In {i}')
         plt.show()
for i in columns:
    after_skewness(df,i)

# %%
for i in df.columns:
  print(i,df[i].skew())
# Out:
# selling_year 0.2951072279677939
# selling_month -0.039507925793557226
# town -0.08504852789270825
# flat_type 0.38969261178555586
# block 0.2564797132909006
# street_name 0.023043790722929416
# storey_range 0.3782310566802314
# floor_area_sqm 0.3321283218916277
# flat_model 0.4991382928909888
# lease_commence_date 0.6358066127725892
# resale_price -0.9865824163990554
# Remaining_lease_float 0

# %%
df
# Out:
#         selling_year  selling_month  town  flat_type  block  street_name  \
# 0               1990              1     0          0    829           13
# 1               1990              1     0          0    829           13
# 2               1990              1     0          0    829           13
# 3               1990              1     0          0    829           13
# 4               1990              1     0          2    447           13
# ...              ...            ...   ...        ...    ...          ...
# 920440          2024              3    26          4    518          566
# 920441          2024              3    26          4   1536          571
# 920442          2024              3    26          4   1844          572
# 920443          2024              3    26          5   2269          554
# 920444          2024              3    26          5   1748          572
#
#         storey_range  floor_area_sqm  flat_model  lease_commence_date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920445 entries, 0 to 920444
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   selling_year           920445 non-null  int64
#  1   selling_month          920445 non-null  int64
#  2   town                   920445 non-null  int64
#  3   flat_type              920445 non-null  int64
#  4   block                  920445 non-null  int64
#  5   street_name            920445 non-null  int64
#  6   storey_range           920445 non-null  float64
#  7   floor_area_sqm         920445 non-null  float64
#  8   flat_model             920445 non-null  int64
#  9   lease_commence_date    920445 non-null  float64
#  10  resale_price           920445 non-null  float64
#  11  Remaining_lease_float  920445 non-null  float64
# dtypes: float64(5), int64(7)
# memory usage: 84.3 MB

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
# Assuming your DataFrame is named 'df'
features = df[['selling_year','selling_month','town', 'flat_type','block','street_name','storey_range','floor_area_sqm','flat_model','lease_commence_date','Remaining_lease_float']]
target = df['resale_price']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.15)

# Create and train a linear regression model
model = DecisionTreeRegressor()
#model= RandomForestRegressor()

#X_train = X_train.replace([np.inf, -np.inf], np.nan)
#X_train = X_train.fillna(X_train.mean())
model.fit(X_train, y_train)

# Replace infinity values with NaN
#X_test = X_test.replace([np.inf, -np.inf], np.nan)
#X_test = X_test.fillna(X_test.mean())

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
acc_rf= round(model.score(X_train, y_train) * 100, 2)

# Now, you can use the trained model to make predictions on new data
# For example, if you have a new data point with 'floor_area_sqm_new' and 'lease_commence_date_new'
new_data_point = np.array([[2024,3,26,5,1748,572,1.386294,4.955827,1.098612,1987,4.553877]])
predicted_price = model.predict(new_data_point)
print(f"Predicted Resale Price for the new data point: {predicted_price[0]}")
print()
metrics = {'R2': r2,
           'Mean Absolute Error': mae,
           'Mean Squared Error': mse,
           'Root Mean Squared Error': rmse,
           "Accuracy " : str(acc_rf)+"%" }

metrics
# Out:
# Predicted Resale Price for the new data point: 12.61183104395786
# {'R2': 0.9709145258785412,
#  'Mean Absolute Error': 0.06804800815975945,
#  'Mean Squared Error': 0.01066463392848323,
#  'Root Mean Squared Error': 0.10326971447855963,
#  'Accuracy ': '99.97%'}

# %% [markdown]
# **Create pickle file**

# %%
import pickle
with open('Singapore_Resale_Price_Pridict _model', 'wb') as f:
    pickle.dump(model, f)

# %%
with open('xtest','wb') as f:
  pickle.dump(X_test,f)

# %%
with open('ytest','wb') as f:
  pickle.dump(y_test,f)
